# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./2018 WOMEN & GIRLS ALLEGEDLY KILLED BY MEN & BOYS © 2016 Women Count USA Femicide Accountability Project  Dawn Wilcox (Copyrighted Material).csv', sep = ',', skip_blank_lines=True, header=1)

# %%
data['RELATIONSHIP'].hist(xrot = 90, bins = data['RELATIONSHIP'].nunique())
plt.xlabel('Relationship')
plt.ylabel('Number of cases')
plt.show()
